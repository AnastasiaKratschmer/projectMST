# %%
from functions_collection_copy import *

# %%
score_matrix={'a': {'a': 0, 'c': 5, 'g': 2, 't': 5}, 'c': {'a': 5, 'c': 0, 'g': 5, 't': 2}, 'g': {'a': 2, 'c': 5, 'g': 0, 't': 5}, 't': {'a': 5, 'c': 2, 'g': 5, 't': 0}}
gap_cost=5

seqs=['acacat','gat','actg']

# %%
new_assembly_gradual_x(seqs,score_matrix,gap_cost, check_integrity=True)

print('END OF GRADUAL')

new_assembly_OBO_x(seqs,score_matrix,gap_cost, check_integrity=True)

print('END OF OBO')

new_assembly_Gus_x(seqs,score_matrix,gap_cost, check_integrity=True)

print('END OF GUS')
# Out:
# matrix for MST: [['' '17' '0' '1']
#  ['' '14' '0' '2']
#  ['' '12' '1' '2']]
# <class 'dict'>
# {'0': [0, 0], '1': [1, 0], '2': [2, 0]}
# <class 'numpy.str_'>
# <class 'numpy.str_'>
# the node1 is right now in the alignment nr 1
# the node2 is right now in the alignment nr 2
# I don't have the case identified yet, but MSA1 is: ['g'] MSA2 is: ['a'] ,and the guide is: ['g', 'a']
# nodes pointing to cols: 0 , 0
# i,j,l: 0,0,0
# max for those should be: 4,3,4
# flag: False
# case:3
# guide_was: ['g', 'a']
# I just made the new col: ['g', 'a']
# MSA_new now has len: 1
# ['g', 'a']
# selected stuff from col made:
# ['g', 'a']
# I don't have the case identified yet, but MSA1 is: ['a'] MSA2 is: ['c'] ,and the guide is: ['a', 'c']
# nodes pointing to cols: 0 , 0
# i,j,l: 1,1,1
# max for those should be: 4,3,4
# flag: False
# case:3
# guide_was: ['a', 'c']
# I just made the new col: ['a', 'c']
# MSA_new now has len: 2
# ['a', 'c']
# selected stuff from col made:
# ['a', 'c']
# ...
