# %%
import pandas as pd

# Replace 'your_file.csv' with the actual file path
file_path = 'testing_outputs/random_strs_tests.csv'

# Read CSV into DataFrame
df = pd.read_csv(file_path)

# Display the DataFrame
print(df)
# Out:
#     nr_of_str  str_len    mode  Kruskal    Prim  Gusfield
# 0           5       10  random      280     280       271
# 1          10       10  random     1677    1619      1445
# 2          15       10  random     4037    4103      3428
# 3           5       50  random     1483    1483      1468
# 4          10       50  random     7413    7327      6627
# ..        ...      ...     ...      ...     ...       ...
# 67         10      750  random   123987  123679     98588
# 68         15      750  random   304113  303755    235773
# 69          5     1000  random    28634   28619     27359
# 70         10     1000  random   157211  157050    132454
# 71         15     1000  random   393646  386349    313725
#
# [72 rows x 6 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = df[df['nr_of_str'] == 10]
print(df)
#Example: Pivot the DataFrame using melt
df = pd.melt(
    df,
   id_vars=['nr_of_str','str_len'],
    value_vars=['Kruskal', 'Prim', 'Gusfield'],
    var_name='type',
    value_name='cost'
)
print(df)


plt.plot(s)
# Out:
#     nr_of_str  str_len    mode  Kruskal    Prim  Gusfield
# 1          10       10  random     1677    1619      1445
# 4          10       50  random     7413    7327      6627
# 7          10      100  random    17084   16800     13699
# 10         10      200  random    33937   32599     26170
# 13         10      300  random    48450   48134     39747
# 16         10      500  random    76467   76142     65476
# 19         10      750  random   115527  115399     99568
# 22         10     1000  random   158649  157843    131597
# 25         10       10  random     1367    1367      1272
# 28         10       50  random     8063    8012      7052
# 31         10      100  random    15592   15552     13938
# 34         10      200  random    31351   31252     26700
# 37         10      300  random    46613   46451     39894
# 40         10      500  random    86684   86064     65736
# 43         10      750  random   104333  104272     96927
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame
# If you don't have seaborn installed, you can install it using: pip install seaborn

# Example: Grouped bar chart
plt.figure(figsize=(10, 6))
custom_palette = {"Kruskal": "#a6cee3", "Prim": "#b2df8a", "Gusfield": "#1f78b4"}

sns.barplot(x='str_len', y='cost', hue='type', data=df,palette=custom_palette)

# Set labels and title
plt.xlabel('String Length')
plt.ylabel('Cost')
plt.title('Cost of alignment of 10 strings using Kruskal MST, Prim MST and Gusfield tree structure as guide (3 reps)')

# Show the plot
plt.show()
